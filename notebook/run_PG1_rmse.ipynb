# %%
import os,sys
import time,datetime
import numpy as np
import pandas as pd

# %%
# path information
groundtruth_csv = '../dataset/open_peer_review_v2/peer_review/translated_groundtruth.csv'
peer_review_csv = '../dataset/open_peer_review_v2/peer_review/peer_review_forPG3.csv'

# preprocess dataset
gDF = pd.read_csv(groundtruth_csv)
rDF = pd.read_csv(peer_review_csv)

# %% [markdown]
# ### PG1

# %%
# %run ../tools/TrainTest.py
# %run ../tools/PG1.py
pg1 = PG1(gDF, rDF)

# %% [markdown]
# #### ↓making rmseWithTruth(self, hyper_list)

# %%
stan_fit = pg1.fit([2.40841889, 6.77462461, 79.11369152, 85.80229935, 21.78680711])
stan_fit
# Out:
# Inference for Stan model: anon_model_8a16fa5f1a4901cc869fc37b72c4603e.
# 4 chains, each with iter=5000; warmup=500; thin=1;
# post-warmup draws per chain=4500, total post-warmup draws=18000.
#
#                    mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# ability[0]         2.62  8.8e-4   0.12   2.38   2.54   2.62    2.7   2.85  18000    1.0
# ability[1]         2.41  1.1e-3   0.15   2.12   2.31   2.41   2.51   2.69  18000    1.0
# ability[2]         2.43  1.1e-3   0.14   2.15   2.34   2.43   2.53   2.72  18000    1.0
# ability[3]         2.61  7.3e-4    0.1   2.42   2.55   2.61   2.68   2.81  18000    1.0
# ability[4]          2.4  1.1e-3   0.15   2.11    2.3    2.4   2.49   2.69  18000    1.0
# ability[5]         2.64  9.9e-4   0.13   2.37   2.54   2.64   2.73    2.9  18000    1.0
# ability[6]         2.45  1.1e-3   0.14   2.17   2.35   2.45   2.55   2.73  18000    1.0
# ...

# %%
eap_value = stan_fit.summary()['summary'][:,0]
estimated = eap_value[0:pg1.userNum]
rmse = sqrt(mean_squared_error(pg1.grade, estimated))
rmse
# Out:
# 1.329301707234081

# %%
# check rmseWithTruth
pg1.rmseWithTruth([2.40841889, 6.77462461, 79.11369152, 85.80229935, 21.78680711])
# Out:
# 1.3292943367256265
