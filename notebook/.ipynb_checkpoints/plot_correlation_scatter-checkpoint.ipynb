# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 比較データの整形、連続値から0~1へ、groundtruth順に予測値も並び替え

# %%
estimated_df = pd.read_csv('../result/pg1w200_mean.csv')
estimated_g = estimated_df['eap'][0:470].get_values()
gdf = pd.read_csv('../dataset/peer_review/translated_groundtruth.csv')
truth = gdf['grade'].get_values()

# %%
def normalize(ndarray):
    min_value = ndarray.min()
    max_value = ndarray.max()
    nor = (ndarray - min_value).astype(float) / (max_value - min_value).astype(float)
    return nor

# %%
plt.figure(figsize=(8, 8))

plt.xlim(-0.02,1.02)
plt.xticks(fontsize=20)
plt.xlabel("True Value",fontsize=20)
plt.ylim(-0.02, 1.02)
plt.yticks(fontsize=20)
plt.ylabel("Estimate Value",fontsize=20)

x = normalize(truth)
y= normalize(estimated_g)
plt.scatter(x,y, s=40)

plt.title("Ability of Evaluator", fontsize=25)
plt.tight_layout()
plt.show()
#plt.savefig(task_name+"/reliability_scatter.eps",bbox_inches="tight", pad_inches=0.1, dpi=300, format = 'eps')

# %%
np.corrcoef(truth,estimated_g)[0,1]
# Out:
# 0.40675485418828622

# %% [markdown]
# pc1

# %%
estimated_df = pd.read_csv('../result/pc1w200_mean.csv')
estimated_c = estimated_df['eap'][0:470].get_values()
gdf = pd.read_csv('../dataset/peer_review/translated_groundtruth.csv')
truth = gdf['grade'].get_values()

# %%
plt.figure(figsize=(8, 8))

plt.xlim(-0.02,1.02)
plt.xticks(fontsize=20)
plt.xlabel("True Value",fontsize=20)
plt.ylim(-0.02, 1.02)
plt.yticks(fontsize=20)
plt.ylabel("Estimate Value",fontsize=20)

x = normalize(truth)
y= normalize(estimated_c)
plt.scatter(x,y, s=40)

plt.title("Ability of Evaluator", fontsize=25)
plt.tight_layout()
plt.show()
#plt.savefig(task_name+"/reliability_scatter.eps",bbox_inches="tight", pad_inches=0.1, dpi=300, format = 'eps')

# %%
np.corrcoef(truth,estimated_c)[0,1]
# Out:
# 0.17575873367973921

# %%
for i in xrange(100):
    theta = i*0.01
    balance = theta*estimated_g + (1-theta)*estimated_c
    print(theta,np.corrcoef(truth, balance)[0,1])
# Out:
# (0.0, 0.17589759806412672)
# (0.01, 0.17942909896857687)
# (0.02, 0.18300162399423484)
# (0.03, 0.18661479325345801)
# (0.04, 0.19026815128194199)
# (0.05, 0.19396116269911828)
# (0.06, 0.1976932078007147)
# (0.07, 0.20146357810241414)
# (0.08, 0.20527147185631348)
# (0.09, 0.20911598956481914)
# (0.1, 0.21299612951967867)
# (0.11, 0.21691078339706113)
# (0.12, 0.22085873194285127)
# (0.13, 0.22483864078568896)
# (0.14, 0.22884905641864042)
# (0.15, 0.23288840239370301)
# (0.16, 0.23695497577660229)
# (0.17, 0.24104694391241857)
# (0.18, 0.24516234155544492)
# (0.19, 0.24929906841924265)
# (0.2, 0.25345488720503107)
# (0.21, 0.2576274221682251)
# (0.22, 0.26181415828406152)
# (0.23, 0.26601244107364896)
# (0.24, 0.27021947715144295)
# (0.25, 0.2744323355538919)
# (0.26, 0.27864794990676639)
# (0.27, 0.28286312148539566)
# (0.28, 0.28707452321758359)
# (0.29, 0.29127870467331035)
# (0.3, 0.29547209807841929)
# (0.31, 0.29965102538127386)
# (0.32, 0.30381170639191829)
# (0.33, 0.30795026800255415)
# (0.34, 0.31206275448627591)
# (0.35000000000000003, 0.31614513885809209)
# (0.36, 0.32019333526838994)
# (0.37, 0.3242032123844622)
# (0.38, 0.3281706077006124)
# (0.39, 0.3320913427020355)
# (0.4, 0.33596123879240819)
# (0.41000000000000003, 0.33977613388016625)
# (0.42, 0.3435318995042308)
# (0.43, 0.34722445836674787)
# (0.44, 0.3508498021285858)
# (0.45, 0.35440400931325433)
# (0.46, 0.35788326315684577)
# (0.47000000000000003, 0.36128386923586719)
# (0.48, 0.36460227270165729)
# (0.49, 0.3678350749496424)
# (0.5, 0.37097904955412569)
# (0.51, 0.37403115730463504)
# (0.52, 0.37698856018811222)
# (0.53, 0.37984863417224951)
# (0.54, 0.38260898065892557)
# (0.55, 0.38526743649272932)
# (0.56, 0.38782208242760158)
# (0.5700000000000001, 0.39027124997441098)
# (0.58, 0.39261352657327259)
# (0.59, 0.39484775905626651)
# (0.6, 0.39697305538837147)
# (0.61, 0.39898878469651794)
# (0.62, 0.40089457561809588)
# (0.63, 0.40269031302073027)
# (0.64, 0.40437613316417498)
# (0.65, 0.4059524173924362)
# (0.66, 0.40741978445949972)
# (0.67, 0.40877908160496507)
# (0.68, 0.41003137450643246)
# (0.6900000000000001, 0.41117793624352)
# (0.7000000000000001, 0.41222023541382508)
# (0.71, 0.41315992354417158)
# (0.72, 0.41399882194104065)
# (0.73, 0.41473890812243464)
# (0.74, 0.41538230196972414)
# (0.75, 0.41593125173246992)
# (0.76, 0.41638812001211284)
# (0.77, 0.41675536984198636)
# (0.78, 0.41703555097162354)
# (0.79, 0.41723128645306734)
# (0.8, 0.41734525961611985)
# (0.81, 0.41738020150837657)
# (0.8200000000000001, 0.41733887886478982)
# (0.8300000000000001, 0.41722408266050864)
# (0.84, 0.41703861729006719)
# (0.85, 0.41678529040580231)
# (0.86, 0.41646690343873538)
# (0.87, 0.41608624281622997)
# (0.88, 0.41564607188249691)
# (0.89, 0.41514912352065308)
# (0.9, 0.41459809346839893)
# (0.91, 0.41399563431361824)
# (0.92, 0.41334435015125376)
# (0.93, 0.4126467918785684)
# (0.9400000000000001, 0.41190545310254179)
# (0.9500000000000001, 0.41112276663034564)
# (0.96, 0.4103011015117965)
# (0.97, 0.40944276060118806)
# (0.98, 0.40854997860498021)
# (0.99, 0.40762492058130062)

# %%
balance = 0.8*estimated_g + (1-0.8)*estimated_c

# %%
np.corrcoef(truth,balance)
# Out:
# array([[ 1.        ,  0.41734526],
#        [ 0.41734526,  1.        ]])

# %%
plt.figure(figsize=(8, 8))

plt.xlim(-0.02,1.02)
plt.ylim(-0.02, 1.02)

x = normalize(truth)
y= normalize(balance)
plt.scatter(x,y, s=40)

plt.tight_layout()
#plt.show()
plt.savefig("../result/display.eps",bbox_inches="tight", pad_inches=0.1, dpi=300, format = 'eps')

# %%
bias_g = estimated_df['eap'][470*2:470*3].get_values()

# %%
bias_c = estimated_df['eap'][470*1:470*2].get_values()

# %%
np.corrcoef(bias_g,bias_c)
# Out:
# array([[ 1.        ,  0.41360996],
#        [ 0.41360996,  1.        ]])

# %% [markdown]
# PCG1

# %%
estimated_df = pd.read_csv('../result/pcg1w200_mean.csv')
estimated_g = estimated_df['eap'][0:470].get_values()
gdf = pd.read_csv('../dataset/peer_review/translated_groundtruth.csv')
truth = gdf['grade'].get_values()

# %%
plt.figure(figsize=(8, 8))

plt.xlim(-0.02,1.02)
plt.xticks(fontsize=20)
plt.xlabel("True Value",fontsize=20)
plt.ylim(-0.02, 1.02)
plt.yticks(fontsize=20)
plt.ylabel("Estimate Value",fontsize=20)

x = normalize(truth)
y= normalize(estimated_g)
plt.scatter(x,y, s=40)

plt.title("Ability of Evaluator", fontsize=25)
plt.tight_layout()
plt.show()
#plt.savefig(task_name+"/reliability_scatter.eps",bbox_inches="tight", pad_inches=0.1, dpi=300, format = 'eps')

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        ,  0.40464166],
#        [ 0.40464166,  1.        ]])
